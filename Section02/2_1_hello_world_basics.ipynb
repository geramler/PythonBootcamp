# %% [markdown]
# # Python Basics - Hello World
#
# Welcome to Section 2 of the Python Bootcamp!
#
# In this notebook, we'll start with the most fundamental Python program - printing "Hello Python!" to the console.
#
# ## Learning Objectives:
# - Understand the `print()` function
# - Learn about Python strings
# - Execute your first Python code
#
# ## The print() Function
# The `print()` function is one of the most commonly used functions in Python. It displays output to the console/screen.

# %%
print("Hello Python!")
# Out:
# Hello Python!

# %% [markdown]
# ## Notes:
# - **Strings**: The text "Hello Python!" is enclosed in double quotes, making it a string
# - **Function call**: `print()` is a function that takes an argument (the string) and displays it
# - **Output**: When you run this cell, you'll see "Hello Python!" printed below
